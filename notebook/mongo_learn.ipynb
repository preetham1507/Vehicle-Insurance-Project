# %%
import pandas as pd
import pymongo

# %%
df = pd.read_csv("data.csv")

# %%
# mongodb is a NoSQL database, It has to be stored in key-value storage form

data = df.to_dict(orient='records')  # list of dictionaries

# %%
DB_NAME = "Proj-1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = 'mongodb+srv://preethamsrinivasgowda_db_user:qB7HjhKWgzYYRKKT@cluster0.sjb6w2u.mongodb.net/?appName=Cluster0'

#above either replace <db_password> with actual password or use fstring to format it

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]  # create database   
collection = data_base[COLLECTION_NAME]  # create collection

# %%
# Uploading data to mongodb
rec = collection.insert_many(data)
